# %%
# !pip install boto3 #install required service.
import boto3 #AWS SDK for python

# %%
import boto3.session
#client = boto3.client('textract', region_name='us-west-2')
#Another way to create session,
client =boto3.client('textract',aws_access_key_id="AKIA3B3RDPXXQYLIKQLW",aws_secret_access_key="VNVux/0oVHKX2CerDp3aENdD/O2+K0hU060/mqnX",region_name="us-west-2")
#AKIA3B3RDPXXQYLIKQLW

# %%
documentName =(r"Image.JPG") #mention path of the document stored in your system.

# %%
with open(documentName, 'rb') as document:
    imageBytes = bytearray(document.read())

# %%
response = client.detect_document_text(Document={'Bytes': imageBytes})

# %%
response
# Out:
# {'DocumentMetadata': {'Pages': 1},
#  'Blocks': [{'BlockType': 'PAGE',
#    'Geometry': {'BoundingBox': {'Width': 0.9892802238464355,
#      'Height': 0.9786633253097534,
#      'Left': 0.0033987441565841436,
#      'Top': 0.01709306612610817},
#     'Polygon': [{'X': 0.00539042241871357, 'Y': 0.01709306612610817},
#      {'X': 0.9782997369766235, 'Y': 0.017463210970163345},
#      {'X': 0.9926789402961731, 'Y': 0.9957563877105713},
#      {'X': 0.0033987441565841436, 'Y': 0.9940615892410278}]},
#    'Id': '3596c398-122e-4fd4-aec6-910bfcd57a7f',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['0b02b154-c305-4d6e-a71e-261a587df023',
#       '5a21b0bc-0c6f-4a69-a0ca-0c08e61a4af9',
#       '8b5e74d1-25ea-4012-85d5-c7653aa83f53',
#       '33eb45b6-752c-403d-aa58-9671ad028cff',
#       '3fa42f3f-1a7f-448a-8681-15a027f31d8b',
#       'e2b32629-db06-4d59-a8e6-7e64e6e851c0',
#       'b8195311-558d-45a6-b64a-e73688986235',
#       '4897afc1-b2ad-4b59-947b-b9d7aae82a1d',
# ...

# %%
for item in response["Blocks"]:
    if item["BlockType"]=="LINE":
        print(item["Text"])
# Out:
# Dr. Anand Jalswal
# --
# Regé 7650014407
# Dr. Bornali Dutta
# - - # 15821 18001
# Na 9650014407
# Dr. Ashish Prakash
# Mobils
# Dr. Pinky Goyal
# Connultant
# pinky
# Mobile
# Regli NA
# Dr. Sandeep Mittal
# Consultant
# Mubile
# Regli
# Dr. Nishant Gupta
# Attending Consultant
# Nishant
# DMC-07352
